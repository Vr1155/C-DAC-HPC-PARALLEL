# %% [markdown]
# # Import the all the necessary libraries:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Import the IPL csv file.

# %%
ipl_auction_df = pd.read_csv("IPL2013.csv")

# %% [markdown]
# # Check the nature of variable:

# %%
type(ipl_auction_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Display the First 5 entires with headers:

# %%
ipl_auction_df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %% [markdown]
# # Finding the summary of DataFrame:
# # See if type is object is it categorical data

# %%
ipl_auction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %% [markdown]
# # To find meta data of frame:

# %%
list(ipl_auction_df)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %% [markdown]
# # Slicing and Indexing a dataframe

# %% [markdown]
# ## 1. By ROWS

# %% [markdown]
# ### First five entries:

# %%
ipl_auction_df[0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %% [markdown]
# ### Last five entries:

# %%
ipl_auction_df[-5:]
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %% [markdown]
# ## 2. By Columns:

# %%
ipl_auction_df['PLAYER NAME'][0:5]
# Out:
# 0     Abdulla, YA
# 1    Abdur Razzak
# 2     Agarkar, AB
# 3       Ashwin, R
# 4    Badrinath, S
# Name: PLAYER NAME, dtype: object

# %% [markdown]
# ## Slicing only 2 columns 5 entries:

# %%
ipl_auction_df[['PLAYER NAME', 'COUNTRY']][0:5]
# Out:
#     PLAYER NAME COUNTRY
# 0   Abdulla, YA      SA
# 1  Abdur Razzak     BAN
# 2   Agarkar, AB     IND
# 3     Ashwin, R     IND
# 4  Badrinath, S     IND

# %% [markdown]
# ## Sorting dataframe by column values:

# %%
ipl_auction_df[['PLAYER NAME', 'SOLD PRICE']].sort_values('SOLD PRICE')[0:5]
# Out:
#        PLAYER NAME  SOLD PRICE
# 73      Noffke, AA       20000
# 46     Kamran Khan       24000
# 0      Abdulla, YA       50000
# 1     Abdur Razzak       50000
# 118  Van der Merwe       50000

# %% [markdown]
# ## Creating New Column to calculate "premium" for each player

# %%
ipl_auction_df['PREMIUM'] = ipl_auction_df['SOLD PRICE'] - ipl_auction_df['BASE PRICE']
ipl_auction_df[['PLAYER NAME', 'BASE PRICE', 'SOLD PRICE', 'PREMIUM']][0:5]
# Out:
#     PLAYER NAME  BASE PRICE  SOLD PRICE  PREMIUM
# 0   Abdulla, YA       50000       50000        0
# 1  Abdur Razzak       50000       50000        0
# 2   Agarkar, AB      200000      350000   150000
# 3     Ashwin, R      100000      850000   750000
# 4  Badrinath, S      100000      800000   700000

# %% [markdown]
# ### Which player got the maximum premium on the base price?

# %%
ipl_auction_df[['PLAYER NAME', 'BASE PRICE', 'SOLD PRICE', 'PREMIUM']].sort_values('PREMIUM', ascending = False)[0:5]
# Out:
#        PLAYER NAME  BASE PRICE  SOLD PRICE  PREMIUM
# 50        Kohli, V      150000     1800000  1650000
# 113     Tiwary, SS      100000     1600000  1500000
# 127   Yuvraj Singh      400000     1800000  1400000
# 111  Tendulkar, SR      400000     1800000  1400000
# 93       Sehwag, V      400000     1800000  1400000

# %% [markdown]
# ## Grouping and Aggregating

# %%
soldprice_by_age = ipl_auction_df.groupby('AGE')['SOLD PRICE'].mean().reset_index()
soldprice_by_age
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %% [markdown]
# # Get only numerical columns from dataset:

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
newdf = ipl_auction_df.select_dtypes(include=numerics)

# %% [markdown]
# ## Correlation operation using pandas

# %%
newdf.corr()
# Out:
#                  Sl.NO.       AGE    T-RUNS    T-WKTS  ODI-RUNS-S  ODI-SR-B  \
# Sl.NO.         1.000000 -0.064235 -0.091722  0.121835   -0.059029  0.042439
# AGE           -0.064235  1.000000  0.469402  0.293473    0.403131  0.038531
# T-RUNS        -0.091722  0.469402  1.000000  0.026285    0.892823  0.231411
# T-WKTS         0.121835  0.293473  0.026285  1.000000   -0.088276  0.012052
# ODI-RUNS-S    -0.059029  0.403131  0.892823 -0.088276    1.000000  0.319264
# ODI-SR-B       0.042439  0.038531  0.231411  0.012052    0.319264  1.000000
# ODI-WKTS       0.098777  0.306949  0.045505  0.822940    0.056554  0.160114
# ODI-SR-BL      0.084678 -0.093574  0.067700  0.060641    0.126795  0.284584
# CAPTAINCY EXP -0.096388  0.323228  0.690647  0.088782    0.714058  0.291373
# RUNS-S        -0.082366  0.002776  0.410143 -0.218544    0.523955  0.306338
# HS            -0.051490  0.083028  0.411209 -0.268432    0.495765  0.360086
# ...

# %% [markdown]
# ## Covariance operation using pandas

# %%
newdf.cov()
# Out:
#                      Sl.NO.           AGE        T-RUNS        T-WKTS  \
# Sl.NO.         1.419167e+03     -1.395349 -1.142209e+04  6.548488e+02
# AGE           -1.395349e+00      0.332499  8.947397e+02  2.414442e+01
# T-RUNS        -1.142209e+04    894.739654  1.092730e+07  1.239692e+04
# T-WKTS         6.548488e+02     24.144425  1.239692e+04  2.035669e+04
# ODI-RUNS-S    -7.965853e+03    832.706500  1.057237e+07 -4.511764e+04
# ODI-SR-B       4.140554e+01      0.575406  1.981138e+04  4.453293e+01
# ODI-WKTS       4.138062e+02     19.682767  1.672783e+04  1.305709e+04
# ODI-SR-BL      8.533721e+01     -1.443459  5.986793e+03  2.314594e+02
# CAPTAINCY EXP -1.693798e+00      0.086941  1.064959e+03  5.908825e+00
# RUNS-S        -1.908961e+03      0.984854  8.341161e+05 -1.918351e+04
# HS            -7.061240e+01      1.742874  4.948391e+04 -1.394223e+03
# AVE           -4.516919e+01      0.368281  1.371761e+04 -4.203209e+02
# ...
